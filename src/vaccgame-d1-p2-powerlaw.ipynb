# %%
import numpy as np
import networkx as nx
import EoN
import matplotlib.pyplot as plt
import csv, random, pdb, sys
from IPython.core.debugger import set_trace
import copy
import pickle as pkl

# %%
sys.path.insert(0, '../lib/')

# %%
from util import *
from graph_utils import *

# %%
G = nx.generators.random_graphs.powerlaw_cluster_graph(10000, 20, 0.3)
len(G)
# Out:
# 10000

# %%
if __name__ == '__main__':
### run for a fixed network and fixed alpha
##########################################

    np.random.seed(0)

    T = 10
    epsilon = 0.001
    alphavals = np.arange(0,50,0.5)
    num_times = 10

    n = len(G)
    p = 0.2
    
    raw_data = []
    exp_inf_list = []
    exp_inf_std = []
    n_vacc_size = []
    xlist_alpha = {}
    ts = {}
    for alpha in alphavals:
        zs = []
        vacc_size = []
        xlist = []
        ts[alpha] = []
        
        print("alpha: ", alpha)

        for i in range(num_times):
            x = {}
            Cvacc = {}
            Cinf = {};
            
            for u in G.nodes():
                x[u] = np.random.randint(0, 2)
                Cinf[u] = 1; 
                Cvacc[u] = Cinf[u]*float(alpha)/n
                
            x, nviol, t = best_response_v2(G, Cvacc, Cinf, x, T, p, epsilon)

            if(nviol == 0):
                
                ts[alpha].append(t)
                
                z = exp_infsize(G, x, p)
                zs.append(z)
                
                vaccinated = len([i for i in x if x[i] == 1])
                vacc_size.append(vaccinated)
                xlist.append(x)

        n_vacc_size.append(vacc_size)
        xlist_alpha[alpha] = xlist
        
        zs = np.array(zs)
        exp_inf_list.append(zs.mean())
        exp_inf_std.append(zs.std())
    
    n_vacc_size = np.array(n_vacc_size)
# Out:
# alpha:  0.0
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# alpha:  0.5
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# alpha:  1.0
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# alpha:  1.5
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# alpha:  2.0
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# alpha:  2.5
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# alpha:  3.0
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# alpha:  3.5
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# alpha:  4.0
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# alpha:  4.5
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp
# init comp
# degree done
# connected components done
# end init comp

# %%
print(exp_inf_list)
print(exp_inf_std)
# Out:
# [0.0, 0.0, 0.0, 6.296043999999998e-05, 0.00023058452, 0.10092850262, 0.24562393179999992, 0.43101863720000005, 0.5207916718800002, 0.6200114763, 0.6682818072, 0.7240351019, 0.75157823352, 0.78818202502, 0.8058550034199999, 0.8272490074600002, 0.8384121311599999, 0.85414177824, 0.86415008914, 0.8743249281000001, 0.8799383111999999, 0.8885214756599998, 0.8933994731, 0.8997139437399998, 0.9035880508999998, 0.9096788232399999, 0.9139913664600001, 0.9179762737400001, 0.92067105668, 0.9244361225999999, 0.92778679982, 0.9306475863000001, 0.9326499288000001, 0.9354381888199998, 0.9373883552199999, 0.9400336784400001, 0.9420094466400002, 0.9436731403599998, 0.9452177780800002, 0.9469154049000001, 0.9481290940999998, 0.9502281363, 0.95141777318, 0.9527518001599999, 0.9535354130399998, 0.9549100406400001, 0.9561031496999999, 0.9568873754600002, 0.9578495123800002, 0.95900992752, 0.9599041791799998, 0.9612022344000002, 0.96147236096, 0.9623942195000001, 0.9630841849199998, 0.9644593914600001, 0.9647628890400002, 0.9658853442199999, 0.9661285914200001, 0.9668810286800001, 0.96750887906, 0.9675973067999999, 0.9683657451200002, 0.96863388796, 0.9688817580799999, 0.9694325396799999, 0.9698504845799999, 0.9703565784999999, 0.9704339773399999, 0.97114940952, 0.9714746085999998, 0.9719079966599999, 0.9726961015399999, 0.97307542674, 0.9731262005, 0.9738084907600003, 0.9741572813600001, 0.9746231317400003, 0.9747378126599999, 0.9747970541400004, 0.9752886927800001, 0.97560881702, 0.9758887085000001, 0.9762042989000002, 0.9765751596599997, 0.9767204288799999, 0.9768687108600002, 0.9773021462999999, 0.9773328513599999, 0.9774619495199998, 0.97757802842, 0.97775147082, 0.9779905643400001, 0.9781343623400002, 0.9780599293199999, 0.97846089662, 0.9782530728, 0.97866261248, 0.9789070565800001, 0.97929754692]
# [0.0, 0.0, 0.0, 6.597257418048854e-07, 6.205902817286145e-06, 0.003287412945123757, 0.003803487054730566, 0.005163784977376814, 0.003990358915236757, 0.003303311648785465, 0.0034273732278475924, 0.002254206082923178, 0.00366154190667537, 0.0020834848059623533, 0.0031284737258112936, 0.001950418585328795, 0.0009763229963997917, 0.0020951216855845385, 0.0014604196197685903, 0.0019619642872782624, 0.0013285188389764785, 0.0018974724925972905, 0.0014517857865552243, 0.001124618065335249, 0.0008133094350478422, 0.0012692615464822352, 0.0007961095052089901, 0.0008286719546294201, 0.0010122624762036242, 0.0009673830058445855, 0.0009988464526314315, 0.000926642524436804, 0.0005425733566048865, 0.0007329028129807473, 0.0011462074670410595, 0.0011941694788603163, 0.0007943125526139287, 0.0010033041497508248, 0.0008419661730318696, 0.0006565132022018222, 0.0008544453513536919, 0.000507326911565026, 0.0011440914677401644, 0.0007517288285150132, 0.0008577909673928413, 0.0008061944132647653, 0.0007517560828715086, 0.0006836176999666646, 0.0005978108351016944, 0.0004120148769376036, 0.0008179995940393711, 0.0005707574022673698, 0.0004900547388647478, 0.0008894419639661465, 0.000731217580296492, 0.0004756653485664895, 0.0005642063318935205, 0.0008449342801015657, 0.00047798332547306584, 0.0005388204998384795, 0.0005991405912893527, 0.00034692736534500975, 0.0006366346572940295, 0.0002685571751291317, 0.0006576350544146336, 0.0005335825600555878, 0.0007030679831352703, 0.0002833429272257677, 0.000660195584995866, 0.0005141032737747605, 0.0006612759713161765, 0.0006816859711369831, 0.0005372840104607889, 0.0003875483993402566, 0.00042228410371353416, 0.0004622098707406509, 0.00036022255752926244, 0.00020099175075003966, 0.0005005762574905727, 0.00044618250237981656, 0.0005611850042718734, 0.000450286289684844, 0.0004342770832006458, 0.0004516489920130561, 0.0002323443640801223, 0.000377502862329805, 0.00038895246867854554, 0.0003172564239660359, 0.0002641565496280135, 0.000174552039825704, 0.00023610203517544217, 0.00018699220317324773, 0.0005179935156213281, 0.0003348924545649249, 0.00016882088221361116, 0.0004299427548452978, 0.0004443865514015982, 0.00039035421337575433, 0.00028111024923383826, 0.00019056879059111635]

# %%
z4 = exp_inf_list
z4std = exp_inf_std

# %%
# print(n_vacc_size)

# %%
n_num_vacc_list = np.array(n_vacc_size)
vacc_mean = n_num_vacc_list.mean(axis = 1)
vacc_std = n_num_vacc_list.std(axis = 1)
print(list(vacc_mean))
print(list(vacc_std))

# %%
k = np.array(vacc_mean).astype(int)
zs, topk_list =  get_topk_exp_infsize(G, k,p) ## sorted by alpha

# %%
jaccard_mean, jaccard_std = plot_jaccard(alphavals, xlist_alpha, topk_list)

# %%
legend = ['Best-response NE', 'Topk Nodes']
plt.plot(alphavals, z4, 'o-')
plt.plot(alphavals, zs, 'o-')
plt.xlabel(r'$\alpha$')
plt.ylabel('E[#inf]')
plt.legend(legend)
plt.savefig('2_3_p4.pdf')

# %%
legend = ['p = ' + str(p)]
for y, ystd in zip(z,zstd):
    plt.errorbar(alphavals, y, ystd, fmt = 'o-')
plt.xlabel(r'$\alpha$')
plt.ylabel('E[#inf]')
plt.legend(legend)
plt.show()

# %%
z = [z4]
zstd = [z4std]
legend = ['p = ' + str('%0.2f'%i) for i in [0.4]]

plt.errorbar(alphavals, vacc_mean, vacc_std, fmt='o-')
plt.xlabel(r'$\alpha$')
plt.ylabel('#vacc')
plt.legend(legend)
plt.savefig('2_1_p4.pdf')

# %%
max([G.degree(v) for v in G.nodes()])

# %%
compare_degree(G, 'whole graph ')
compare_cc(G, 'whole graph ')

# %%
for alpha in range(15):
    v = set(get_provax(xlist_alpha[alpha][0]))
    s = G.subgraph(v)

    compare_degree(s, 'vaccinated nodes alpha: ' + str(alpha))
    compare_cc(s, 'vaccinated nodes alpha: ' + str(alpha))
